# %%
import rdkit
from rdkit import Chem, DataStructs
from rdkit.Chem import AllChem as Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import SimilarityMaps
from rdkit.Chem.Fingerprints import FingerprintMols
from rdkit.Chem import rdFMCS
import random
import os
import pandas as pd
import matplotlib.pylab as plt
# %matplotlib inline

# %% [markdown]
# # Just replace atoms

# %%
class Chromosome(Chem.rdchem.Mol):
    def __init__(self, genes, fitness):
        Chem.rdchem.Mol.__init__(self)
        self.Genes = genes
        self.Fitness = fitness
        self.Mol = Chem.MolFromSmiles(genes)
def get_fitness(genes, target):
    ms = [Chem.MolFromSmiles(target), Chem.MolFromSmiles(genes)]
    fps = [FingerprintMols.FingerprintMol(x) for x in ms]
    return DataStructs.FingerprintSimilarity(fps[0],fps[1])
def mutate(parent, geneSet, get_fitness):
    childGenes = parent
    while True:
        oldGene, alternate = random.sample(range(0,childGenes.Mol.GetNumAtoms()), 2)
        if childGenes.Mol.GetAtomWithIdx(alternate).IsInRing() == False and\
                childGenes.Mol.GetAtomWithIdx(oldGene).IsInRing() == False:
            break
    newGene = random.sample(geneSet, 1)[0]
    try:
        childGenes.Mol.GetAtomWithIdx(alternate).SetAtomicNum(newGene) if\
              childGenes.Mol.GetAtomWithIdx(oldGene).GetFormalCharge() != 0 else\
              childGenes.Mol.GetAtomWithIdx(oldGene).SetAtomicNum(newGene)
        Chem.SanitizeMol(childGenes.Mol)
        genes = Chem.MolToSmiles(childGenes.Mol)
        fitness = get_fitness(genes, target)
        return Chromosome(genes, fitness)
    except:
        genes = Chem.MolToSmiles(parent.Mol)
        return Chromosome(genes, 0)
        pass

# %%
target = "CNCN[NH+]1C=CN(C1C)C"
geneSet = [5,6,7,8,9,15,16] #B,C,N,O,F,P,S
genes = "CCCC[NH+]1C=CN(C1C)C"
fitness = get_fitness(genes, target)
parent = Chromosome(genes,fitness)
print(parent.Fitness)
while parent.Fitness < 0.6:
    child = mutate(parent, geneSet, get_fitness)
    if child.Fitness > parent.Fitness:
        print("child adopted!",child.Genes)
        parent = child
# Out:
# 0.36524822695035464
# child adopted! CC1N(C)C=C[NH+]1SCCS
# child adopted! NN1C=C[NH+](CBOS)C1S
# child adopted! CC1N(C)C=C[NH+]1NPSN
# child adopted! CC1N(C)C=C[NH+]1NCPN

# %%
target = "CNCN[NH+]1C=CN(C1C)C"
geneSet = [5,6,7,8,9,15,16] #B,C,N,O,F,P,S
genes = "CCCC[NH+]1C=CN(C1C)C"
fitness = get_fitness(genes, target)
parent = Chromosome(genes,fitness)
print(parent.Fitness)
while parent.Fitness < 1:
    childGenes = parent
    while True:
        oldGene, alternate = random.sample(range(0, childGenes.Mol.GetNumAtoms()), 2)
        if childGenes.Mol.GetAtomWithIdx(alternate).IsInRing() == False and\
              childGenes.Mol.GetAtomWithIdx(oldGene).IsInRing() == False:
            break    
    newGene = random.sample(geneSet, 1)[0]
    try:
        childGenes.Mol.GetAtomWithIdx(alternate).SetAtomicNum(newGene) if\
            childGenes.Mol.GetAtomWithIdx(oldGene).GetFormalCharge() != 0 else\
            childGenes.Mol.GetAtomWithIdx(oldGene).SetAtomicNum(newGene)
        Chem.SanitizeMol(childGenes.Mol)
    except:
        print("Sanitization Failure")
    genes = Chem.MolToSmiles(childGenes.Mol)
    childFitness = get_fitness(genes, target)
    if childFitness > parent.Fitness:
        parent = childGenes
        print(genes, childFitness)
    Chem.MolToSmiles(childGenes.Mol)
ax=Draw.MolToMPL(childGenes.Mol)
# Out:
# 0.36524822695035464
# CCCC[NH+]1C=CN(O)C1C 0.378125
# CCCC[NH+]1C=CN(O)C1C 0.378125
# CCCC[NH+]1C=CN(O)C1C 0.378125
# BCCC[NH+]1C=CN(O)C1C 0.39556962025316456
# CCCC[NH+]1C=CN(O)C1C 0.378125
# Sanitization Failure
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# <ipython-input-26-a7903154faeb> in <module>()
#      18         print("Sanitization Failure")
#      19     genes = Chem.MolToSmiles(childGenes.Mol)
# ---> 20     childFitness = get_fitness(genes, target)
#      21     if childFitness > parent.Fitness:
#      22         parent = childGenes
#
# <ipython-input-13-407e3372dd57> in get_fitness(genes, target)
#       7 def get_fitness(genes, target):
#       8     ms = [Chem.MolFromSmiles(target), Chem.MolFromSmiles(genes)]
# ----> 9     fps = [FingerprintMols.FingerprintMol(x) for x in ms]
#      10     return DataStructs.FingerprintSimilarity(fps[0],fps[1])
#
# <ipython-input-13-407e3372dd57> in <listcomp>(.0)
#       7 def get_fitness(genes, target):
#       8     ms = [Chem.MolFromSmiles(target), Chem.MolFromSmiles(genes)]
# ----> 9     fps = [FingerprintMols.FingerprintMol(x) for x in ms]
#      10     return DataStructs.FingerprintSimilarity(fps[0],fps[1])
#
# /home/wesley/anaconda3/envs/py34/lib/python3.4/site-packages/rdkit/Chem/Fingerprints/FingerprintMols.py in FingerprintMol(mol, fingerprinter, **fpArgs)
#      72                        fpArgs['fpSize'],fpArgs['bitsPerHash'],
#      73                        fpArgs['useHs'],fpArgs['tgtDensity'],
# ---> 74                        fpArgs['minSize'])
#      75   return fp
#      76
#
# ArgumentError: Python argument types in
#     rdkit.Chem.rdmolops.RDKFingerprint(NoneType, int, int, int, int, int, float, int)
# did not match C++ signature:
#     RDKFingerprint(RDKit::ROMol mol, unsigned int minPath=1, unsigned int maxPath=7, unsigned int fpSize=2048, unsigned int nBitsPerHash=2, bool useHs=True, double tgtDensity=0.0, unsigned int minSize=128, bool branchedPaths=True, bool useBondOrder=True, boost::python::api::object atomInvariants=0, boost::python::api::object fromAtoms=0, boost::python::api::object atomBits=None, boost::python::api::object bitInfo=None)

# %%
geneSet = [5,6,7,8,9,15,16] #B,C,N,O,F,P,S
genes = "CCCC[NH+]1C=CN(C1C)C"
fitness = 20
parent = Chromosome(genes,fitness)
while True:
    oldGene, alternate = random.sample(range(0,parent.Mol.GetNumAtoms()-1), 2)
    if parent.Mol.GetAtomWithIdx(alternate).IsInRing() == False and\
          parent.Mol.GetAtomWithIdx(oldGene).IsInRing() == False:
        break    
newGene = random.sample(geneSet, 1)[0]
print(newGene)
try:
    parent.Mol.GetAtomWithIdx(alternate).SetAtomicNum(newGene) if\
        parent.Mol.GetAtomWithIdx(oldGene).GetFormalCharge() != 0 else\
        parent.Mol.GetAtomWithIdx(oldGene).SetAtomicNum(newGene)
    Chem.SanitizeMol(parent.Mol)
except:
    print("Sanitization failure")
Chem.MolToSmiles(parent.Mol)
ax=Draw.MolToMPL(parent.Mol)
# Out:
# 6

# %%
while True:
    oldGene, alternate = random.sample(range(0,parent.Mol.GetNumAtoms()-1), 2)
    if parent.Mol.GetAtomWithIdx(alternate).IsInRing() == False and\
            parent.Mol.GetAtomWithIdx(oldGene).IsInRing() == False:
        break

# %%
geneSet = [5,6,7,8,9,15,16] #B,C,N,O,F,P,S
parent = Chem.MolFromSmiles("NCNC[NH+]1C=CN(C1C)C")
oldGene, alternate = random.sample(range(0,parent.GetNumAtoms()-1),2)
newGene = random.sample(geneSet, 1)[0]
parent.GetAtomWithIdx(alternate).SetAtomicNum(newGene) if\
    parent.GetAtomWithIdx(oldGene).GetFormalCharge() != 0 else\
    parent.GetAtomWithIdx(oldGene).SetAtomicNum(newGene)
Chem.MolToSmiles(parent)
# Out:
# 'CC1N(C)C=C[NH+]1CNCF'

# %%
replace_atom = random.randint(0,len(potential_bond_sites)-1)
new_atom = random.sample(geneSet, 2)[0]
if potential_bond_sites[replace_atom] > 0:
    mol.GetAtomWithIdx(replace_atom).SetAtomicNum(new_atom)
Chem.SanitizeMol(mol)
Chem.MolToSmiles(mol)
ax1=Draw.MolToMPL(mol)

# %% [markdown]
# # Add some atoms and shit like that

# %%
target = "CCCC[NH+]1C=CN(C1C)C"
genes = "[NH+]1C=CN(C1C)C"

m = Chem.MolFromSmiles(genes)
mw = Chem.RWMol(m)
mw.AddAtom(Chem.Atom(6))
mw.AddAtom(Chem.Atom(6))
mw.AddAtom(Chem.Atom(6))
mw.AddAtom(Chem.Atom(6))

mw.AddBond(6,7,Chem.BondType.SINGLE)
mw.AddBond(7,8,Chem.BondType.SINGLE)
mw.AddBond(8,9,Chem.BondType.SINGLE)
mw.AddBond(0,10,Chem.BondType.SINGLE)
mw.UpdatePropertyCache(strict=True)

for atom in mw.GetAtoms():
    print("{}\t{}\t{}".format("atom %s ring status and valence:"\
            # %atom.GetSymbol(), atom.IsInRing(), atom.GetExplicitValence()))
Chem.SanitizeMol(mw)
Chem.MolToSmiles(mw)
ax=Draw.MolToMPL(mw)

target_chrome = Chromosome(target,fitness)
target = Chem.MolToSmiles(target_chrome.Mol)
genes = Chem.MolToSmiles(mw)
parent = Chromosome(genes,fitness)
genes = Chem.MolToSmiles(parent.Mol)
fitness = get_fitness(genes, target)
parent.Fitness
# Out:
# atom N ring status and valence:	True	4
# atom C ring status and valence:	True	3
# atom C ring status and valence:	True	3
# atom N ring status and valence:	True	3
# atom C ring status and valence:	True	3
# atom C ring status and valence:	False	1
# atom C ring status and valence:	False	2
# atom C ring status and valence:	False	2
# atom C ring status and valence:	False	2
# atom C ring status and valence:	False	1
# atom C ring status and valence:	False	1
# 1.0

# %%
m = Chem.MolFromSmiles('CC(=O)C=CC=C')
mw = Chem.RWMol(m)
ax=Draw.MolToMPL(mw)
mw.ReplaceAtom(4,Chem.Atom(7))
ax=Draw.MolToMPL(mw)
mw.AddAtom(Chem.Atom(6))
ax=Draw.MolToMPL(mw)
mw.AddAtom(Chem.Atom(6))
ax=Draw.MolToMPL(mw)
mw.AddBond(6,7,Chem.BondType.SINGLE)
ax=Draw.MolToMPL(mw)
mw.AddBond(7,8,Chem.BondType.DOUBLE)
ax=Draw.MolToMPL(mw)
mw.AddBond(8,3,Chem.BondType.SINGLE)
ax=Draw.MolToMPL(mw)
mw.RemoveAtom(0)
ax=Draw.MolToMPL(mw)
mw.GetNumAtoms()
Chem.MolToSmiles(mw)
Chem.SanitizeMol(mw)
Chem.MolToSmiles(mw)
ax=Draw.MolToMPL(mw)

# %%
from rdkit.Chem import FragmentCatalog
from rdkit import RDConfig
fName=os.path.join(RDConfig.RDDataDir,'FunctionalGroups.txt')
fparams = FragmentCatalog.FragCatParams(1,6,fName)
fparams.GetNumFuncGroups()
# Out:
# 39

# %%
fcat=FragmentCatalog.FragCatalog(fparams)
fcgen=FragmentCatalog.FragCatGenerator()
m = Chem.MolFromSmiles('OCC=CC(=O)O')
fcgen.AddFragsFromMol(m,fcat)
# Out:
# 3

# %%
start = "NCNC[NH+]1C=CN(C1C)C"
target = "CCCC[NH+]1C=CN(C1C)C"
mol = Chem.MolFromSmiles(target)
print("{}\t{}".format("number of atoms: ", mol.GetNumAtoms()))
for atom in mol.GetAtoms():
    print("{}\t{}\t{}".format("atom %s ring status and valence:"\
            # %atom.GetSymbol(), atom.IsInRing(), atom.GetExplicitValence()))
ax1=Draw.MolToMPL(mol)
# Out:
# number of atoms: 	11
# atom N ring status and valence:	False	1
# atom C ring status and valence:	False	2
# atom N ring status and valence:	False	2
# atom C ring status and valence:	False	2
# atom N ring status and valence:	True	4
# atom C ring status and valence:	True	3
# atom C ring status and valence:	True	3
# atom N ring status and valence:	True	3
# atom C ring status and valence:	True	3
# atom C ring status and valence:	False	1
# atom C ring status and valence:	False	1

# %%
df = pd.read_csv("saltInfo.csv")
mol1 = Chem.MolFromSmiles(df["cation_SMILES"][0])
mol2 = Chem.MolFromSmiles(df["cation_SMILES"][1])
mols = [mol1,mol2]
res=rdFMCS.FindMCS(mols)
mol = Chem.MolFromSmarts(res.smartsString)
print("{}\t{}".format("number of atoms: ", mol.GetNumAtoms()))
for atom in mol.GetAtoms():
    print("{}\t{}".format("atom %s ring status:"\
            # %atom.GetSymbol(), atom.IsInRing()))
ax1=Draw.MolToMPL(mol1)
ax2=Draw.MolToMPL(mol2)
# Out:
# number of atoms: 	8
# atom C ring status:	False
# atom C ring status:	False
# atom N ring status:	False
# atom C ring status:	False
# atom C ring status:	False
# atom N ring status:	False
# atom C ring status:	False
# atom C ring status:	False

# %%
mol.GetAtomWithIdx(0).SetAtomicNum(7)

# %%
target = "CCCC[NH+]1C=CN(C1C)C"
mol = Chem.MolFromSmiles(target)
potential_bond_sites=[]
print("{}\t{}".format("number of atoms: ", mol.GetNumAtoms()))
for atom in mol.GetAtoms():
    print("{}\t{}\t{}".format("atom %s ring status and valence:"\
            # %atom.GetSymbol(), atom.IsInRing(), atom.GetExplicitValence()))
    if atom.GetSymbol() == 'C':
        potential_bond_sites.append(4-atom.GetExplicitValence())
    if atom.GetSymbol() == 'N':
        potential_bond_sites.append(3-atom.GetExplicitValence())
ax1=Draw.MolToMPL(mol)
potential_bond_sites
# Out:
# number of atoms: 	11
# atom C ring status and valence:	False	1
# atom C ring status and valence:	False	2
# atom C ring status and valence:	False	2
# atom C ring status and valence:	False	2
# atom N ring status and valence:	True	4
# atom C ring status and valence:	True	3
# atom C ring status and valence:	True	3
# atom N ring status and valence:	True	3
# atom C ring status and valence:	True	3
# atom C ring status and valence:	False	1
# atom C ring status and valence:	False	1
# [3, 2, 2, 2, -1, 1, 1, 0, 1, 3, 3]
